# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\raw_students.csv")

# %%
df
# Out:
#    StudentID          Name     Age  Gender  Score                Email
# 0          1      John doe      20    male   85.0     john@example.com
# 1          2   Jane Smith       19  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson     NaN    Male   78.0       bobj@email.com
# 3          4   Alice Brown      21  Female    NaN      alice@email.com
# 4          5     Chris Lee  twenty    Male   88.0          chris@email
# 5          6      John Doe      20    Male   85.0     john@example.com
# 6          7           NaN      22  Female   92.0      sarah@email.com
# 7          8  Michael King      23    Male   75.0    michael@email.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  8 non-null      int64
#  1   Name       7 non-null      object
#  2   Age        7 non-null      object
#  3   Gender     8 non-null      object
#  4   Score      7 non-null      float64
#  5   Email      8 non-null      object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 516.0+ bytes

# %%
df["Age"] = pd.to_numeric(df["Age"],errors="coerce")

# %%
df
# Out:
#    StudentID          Name   Age  Gender  Score                Email
# 0          1      John doe  20.0    male   85.0     john@example.com
# 1          2   Jane Smith   19.0  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson   NaN    Male   78.0       bobj@email.com
# 3          4   Alice Brown  21.0  Female    NaN      alice@email.com
# 4          5     Chris Lee   NaN    Male   88.0          chris@email
# 5          6      John Doe  20.0    Male   85.0     john@example.com
# 6          7           NaN  22.0  Female   92.0      sarah@email.com
# 7          8  Michael King  23.0    Male   75.0    michael@email.com

# %%
df.isnull().sum()
# Out:
# StudentID    0
# Name         1
# Age          2
# Gender       0
# Score        1
# Email        0
# dtype: int64

# %%
df["Age"].fillna(df["Age"].fillna(value=df["Age"].mean(),inplace=True)
# Out:
#   Cell In[13], line 1
#     df["Age"].fillna(df["Age"].fillna(value=df["Age"].mean(),inplace=True)
#                                                                           ^
# SyntaxError: incomplete input

# %%
df
# Out:
#    StudentID          Name   Age  Gender  Score                Email
# 0          1      John doe  20.0    male   85.0     john@example.com
# 1          2   Jane Smith   19.0  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson  19.0    Male   78.0       bobj@email.com
# 3          4   Alice Brown  21.0  Female    NaN      alice@email.com
# 4          5     Chris Lee  21.0    Male   88.0          chris@email
# 5          6      John Doe  20.0    Male   85.0     john@example.com
# 6          7           NaN  22.0  Female   92.0      sarah@email.com
# 7          8  Michael King  23.0    Male   75.0    michael@email.com

# %%
df["Score"].fillna(df["Score"].median(), inplace= True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12860\867358300.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Score"].fillna(df["Score"].median(), inplace= True)

# %%
df
# Out:
#    StudentID          Name   Age  Gender  Score                Email
# 0          1      John doe  20.0    male   85.0     john@example.com
# 1          2   Jane Smith   19.0  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson  19.0    Male   78.0       bobj@email.com
# 3          4   Alice Brown  21.0  Female   85.0      alice@email.com
# 4          5     Chris Lee  21.0    Male   88.0          chris@email
# 5          6      John Doe  20.0    Male   85.0     john@example.com
# 6          7           NaN  22.0  Female   92.0      sarah@email.com
# 7          8  Michael King  23.0    Male   75.0    michael@email.com

# %%
df["Age"] = df["Age"]

# %%
df["Name"] = df["Name"].fillna("unknown")

# %%
df
# Out:
#    StudentID          Name   Age  Gender  Score                Email
# 0          1      John doe  20.0    male   85.0     john@example.com
# 1          2   Jane Smith   19.0  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson  19.0    Male   78.0       bobj@email.com
# 3          4   Alice Brown  21.0  Female   85.0      alice@email.com
# 4          5     Chris Lee  21.0    Male   88.0          chris@email
# 5          6      John Doe  20.0    Male   85.0     john@example.com
# 6          7       unknown  22.0  Female   92.0      sarah@email.com
# 7          8  Michael King  23.0    Male   75.0    michael@email.com

# %%
df["Name"].duplicated().sum()
# Out:
# 0

# %%
df.Name.drop_duplicates(inplace = True)

# %%
df
# Out:
#    StudentID          Name   Age  Gender  Score                Email
# 0          1      John doe  20.0    male   85.0     john@example.com
# 1          2   Jane Smith   19.0  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson  19.0    Male   78.0       bobj@email.com
# 3          4   Alice Brown  21.0  Female   85.0      alice@email.com
# 4          5     Chris Lee  21.0    Male   88.0          chris@email
# 5          6      John Doe  20.0    Male   85.0     john@example.com
# 6          7       unknown  22.0  Female   92.0      sarah@email.com
# 7          8  Michael King  23.0    Male   75.0    michael@email.com

# %%
df.drop(5)
# Out:
#    StudentID          Name   Age  Gender  Score                Email
# 0          1      John doe  20.0    male   85.0     john@example.com
# 1          2   Jane Smith   19.0  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson  19.0    Male   78.0       bobj@email.com
# 3          4   Alice Brown  21.0  Female   85.0      alice@email.com
# 4          5     Chris Lee  21.0    Male   88.0          chris@email
# 6          7       unknown  22.0  Female   92.0      sarah@email.com
# 7          8  Michael King  23.0    Male   75.0    michael@email.com

# %%
df.shape
# Out:
# (8, 6)

# %%
df["Gender"] = df["Gender"].str.capitalize()

# %%
df
# Out:
#    StudentID          Name   Age  Gender  Score                Email
# 0          1      John doe  20.0    Male   85.0     john@example.com
# 1          2   Jane Smith   19.0  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson  19.0    Male   78.0       bobj@email.com
# 3          4   Alice Brown  21.0  Female   85.0      alice@email.com
# 4          5     Chris Lee  21.0    Male   88.0          chris@email
# 5          6      John Doe  20.0    Male   85.0     john@example.com
# 6          7       unknown  22.0  Female   92.0      sarah@email.com
# 7          8  Michael King  23.0    Male   75.0    michael@email.com

# %%
df["Age"]=df["Age"].astype("int")

# %%
df.dtypes
# Out:
# StudentID      int64
# Name          object
# Age            int32
# Gender        object
# Score        float64
# Email         object
# dtype: object

# %%
df[df["Email"].str.contains(r".com")]
# Out:
#    StudentID          Name  Age  Gender  Score                Email
# 0          1      John doe   20    Male   85.0     john@example.com
# 1          2   Jane Smith    19  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson   19    Male   78.0       bobj@email.com
# 3          4   Alice Brown   21  Female   85.0      alice@email.com
# 5          6      John Doe   20    Male   85.0     john@example.com
# 6          7       unknown   22  Female   92.0      sarah@email.com
# 7          8  Michael King   23    Male   75.0    michael@email.com

# %%
df["Email"]=df["Email"].str.contains(".com")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df["Email"]=df["Email"].str.contains(".com")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df
# Out:
#    StudentID          Name  Age  Gender  Score  Email
# 0          1      John doe   20    Male   85.0   True
# 1          2   Jane Smith    19  Female   90.0   True
# 2          3   Bob Johnson   19    Male   78.0   True
# 3          4   Alice Brown   21  Female   85.0   True
# 4          5     Chris Lee   21    Male   88.0  False
# 5          6      John Doe   20    Male   85.0   True
# 6          7       unknown   22  Female   92.0   True
# 7          8  Michael King   23    Male   75.0   True

# %%
df=df[df["Email"].str.contains(r".com", regex = False, na=False)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df=df[df["Email"].str.contains(r".com", regex = False, na=False)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df
# Out:
#    StudentID          Name  Age  Gender  Score  Email
# 0          1      John doe   20    Male   85.0   True
# 1          2   Jane Smith    19  Female   90.0   True
# 2          3   Bob Johnson   19    Male   78.0   True
# 3          4   Alice Brown   21  Female   85.0   True
# 4          5     Chris Lee   21    Male   88.0  False
# 5          6      John Doe   20    Male   85.0   True
# 6          7       unknown   22  Female   92.0   True
# 7          8  Michael King   23    Male   75.0   True

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %%
data = pd.read_csv(r"C:\Users\DELL\Downloads\sample2.csv")
data.head
# Out:
# <bound method NDFrame.head of     Unnamed: 0  Age  Salary  Experience  Monthly_Sales
# 0            0   22   30000           1            200
# 1            1   25   32000           2            220
# 2            2   28   35000           3            250
# 3            3   30   40000           5            300
# 4            4   24   38000           4            280
# 5            5   27   36000           3            260
# 6            6   29   37000           4            270
# 7            7   31   39000           6            290
# 8            8   26   41000           5            310
# 9            9   23   42000           2            320
# 10          10   32   45000           7            330
# 11          11   33   47000           8            350
# 12          12   29   44000           6            340
# 13          13   28   43000           5            360
# 14          14   27   46000           4            370
# 15          15   26   48000           3            380
# 16          16   30   50000           5            390
# 17          17   31   52000           6            400
# 18          18   24   31000           2            210
# 19          19   25   33000           1            230
# 20          20  100  200000          30           2000
# 21          21  105  250000          35           2500
# 22          22   19   28000           0            180
# 23          23   21   29000           1            190
# 24          24   22   30000           2            210>

# %%
data = pd.read_csv(r"C:\Users\DELL\Downloads\sample2.csv")
data.head()
# Out:
#    Unnamed: 0  Age  Salary  Experience  Monthly_Sales
# 0           0   22   30000           1            200
# 1           1   25   32000           2            220
# 2           2   28   35000           3            250
# 3           3   30   40000           5            300
# 4           4   24   38000           4            280

# %%
data.head()
# Out:
#    Unnamed: 0  Age  Salary  Experience  Monthly_Sales
# 0           0   22   30000           1            200
# 1           1   25   32000           2            220
# 2           2   28   35000           3            250
# 3           3   30   40000           5            300
# 4           4   24   38000           4            280

# %%
data.describe()
# Out:
#        Unnamed: 0         Age         Salary  Experience  Monthly_Sales
# count   25.000000   25.000000      25.000000   25.000000      25.000000
# mean    12.000000   32.680000   53840.000000    6.000000     445.600000
# std      7.359801   21.332135   52469.578488    8.266398     551.815791
# min      0.000000   19.000000   28000.000000    0.000000     180.000000
# 25%      6.000000   24.000000   33000.000000    2.000000     230.000000
# 50%     12.000000   27.000000   40000.000000    4.000000     300.000000
# 75%     18.000000   30.000000   46000.000000    6.000000     360.000000
# max     24.000000  105.000000  250000.000000   35.000000    2500.000000

# %% [raw]
# (1.5*IQR) TO EXTEND THE DATA
# lowerlimit=Q1-1.5*IQR
# upperlimit=Q3+1.5*IQR

# %%
fig, axs = plt.subplots(1,4,figsize = (16,6))
axs[0].boxplot(data.Age)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 3
#       1 fig, axs = plt.subplots(1,4,figsize = (16,6))
#       2 axs[0].boxplot(data.Age)
# ----> 3 plot.show()
#
# NameError: name 'plot' is not defined

# %%
fig, axs = plt.subplots(1,4,figsize = (16,6))
axs[0].boxplot(data.Age)
axs[1].boxplot(data.Salary)
axs[2].boxplot(data.Experience)
axs[3].boxplot(data.Monthly_Sales)

plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 7
#       4 axs[2].boxplot(data.Experience)
#       5 axs[3].boxplot(data.Monthly_Sales)
# ----> 7 plot.show()
#
# NameError: name 'plot' is not defined

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3-Q1

# %%
IQR
# Out:
# Unnamed: 0          12.0
# Age                  6.0
# Salary           13000.0
# Experience           4.0
# Monthly_Sales      130.0
# dtype: float64

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR

# %%
upper_limit , lower_limit
# Out:
# (Unnamed: 0          36.0
#  Age                 39.0
#  Salary           65500.0
#  Experience          12.0
#  Monthly_Sales      555.0
#  dtype: float64,
#  Unnamed: 0         -12.0
#  Age                 15.0
#  Salary           13500.0
#  Experience          -4.0
#  Monthly_Sales       35.0
#  dtype: float64)

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR

# %%
outliers = ((data < lower_limit) | (data > upper_limit)).any(axis = 1)
data[outliers]
# Out:
#     Unnamed: 0  Age  Salary  Experience  Monthly_Sales
# 20          20  100  200000          30           2000
# 21          21  105  250000          35           2500

# %%
outliers
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21     True
# 22    False
# 23    False
# 24    False
# dtype: bool

# %%
outliers = ((data < lower_limit) | (data > upper_limit)).any(axis = 1)
outlier_data = data[outliers]
cleaned_data = data[~outliers]

# %%
cleaned_data.head()
# Out:
#    Unnamed: 0  Age  Salary  Experience  Monthly_Sales
# 0           0   22   30000           1            200
# 1           1   25   32000           2            220
# 2           2   28   35000           3            250
# 3           3   30   40000           5            300
# 4           4   24   38000           4            280

# %%
fig, axs = plt.subplots(1,4,figsize = (16,6))
axs[0].boxplot(cleaned_data.Age)
axs[1].boxplot(cleaned_data.Salary)
axs[2].boxplot(cleaned_data.Experience)
axs[3].boxplot(cleaned_data.Monthly_Sales)

plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 7
#       4 axs[2].boxplot(cleaned_data.Experience)
#       5 axs[3].boxplot(cleaned_data.Monthly_Sales)
# ----> 7 plot.show()
#
# NameError: name 'plot' is not defined

# %%
data.head()
# Out:
#    Unnamed: 0  Age  Salary  Experience  Monthly_Sales
# 0           0   22   30000           1            200
# 1           1   25   32000           2            220
# 2           2   28   35000           3            250
# 3           3   30   40000           5            300
# 4           4   24   38000           4            280

# %%
z_score =np.abs(zscore(data))
z_score_mask = (z_score > 3).any(axis=1)

# %%
data[z_score_mask]
# Out:
#     Unnamed: 0  Age  Salary  Experience  Monthly_Sales
# 20          20  100  200000          30           2000
# 21          21  105  250000          35           2500
